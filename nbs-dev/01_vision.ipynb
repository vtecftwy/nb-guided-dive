# %% [markdown]
# # vision
# > Functions and classes to make notebooks for computer vision easier to handle

# %%
# | default_exp vision

# %% [markdown]
# List of all packages and objects which should be imported and accessible from the guided dive notebook

# %%
# | export
imported_objects  = ['np', 'pd','shutil', 'Path', 'display_image_cleaner']
try:
    __all__.extend(imported_objects)
except:
    __all__ = imported_objects

# %%
# | hide
from nbdev import show_doc
from fastcore.docments import DocmentTbl

# %%
# | export

import numpy as np
import pandas as pd
import matplotlib as mpl
import os
import time

from ddgs import DDGS
from ddgs.exceptions import DDGSException, TimeoutException, RatelimitException
from fastai.vision.utils import download_images
from pathlib import Path
from PIL import Image
from nb_guided_dive.core import ml_process, config_fastai_for_dive

# %%
# | export
def get_images(
    keywords:str,               # string of keywords/query to search for, e.g. "cat", "cat, not dog", "cat OR dog" 
    label: str,                 # label to give to the images found for the keywords/query, e.g. "cat"    
    path: str | Path,           # path where to download the images, e.g. "data/images"
    max_results: int = 100,     # maximum number of images to download for the keywords
    max_pages: int = 15,        # maximum number of search pages to go through to find the images for the keywords
    skip_download: bool = False # if True, only print the urls of the images found without downloading them (for testing purposes)
    ):
    """Retrieve images search results based on a list of keywords"""
    def _ddgs_call():
        """Wrapper function to call to DDGS."""
        return DDGS().images(
            query=keywords,
            region="wt-wt",
            safesearch="on",
            size=None,
            color="color",
            type_image='photo',
            layout=None,
            license_image=None,
            max_results=max_results,
            page=page,
        )
    
    nb_imgs, page = 0, 1
    while nb_imgs < max_results and page < max_pages:
        print(f"Searching for {max_results} images for {label} (page {page}). {nb_imgs} images found so far...")
        try:
            results = _ddgs_call()
        except TimeoutException as e:
            print("Timeout, retrying once...")
            results = _ddgs_call()            
        except RatelimitException as e:
            print("Rate limited, sleeping 20 sec before retry...")
            time.sleep(20)
            results = _ddgs_call()
        except DDGSException as e:
            print(f"Other DDGS error, retrying once... Error message: {e}")
            results = _ddgs_call()

        if len(results) == 0:
            if page == 1:
                print(f"Not images found for {keywords}")
            else:
                print(f"Only {nb_imgs} images found for {keywords} after {page} pages of search results")                  
            break
        else:
            path2imgs = path / label
            os.makedirs(path2imgs, exist_ok=True)
            urls = [r['image'] for r in results]
            if len(urls) > max_results - nb_imgs:
                # only pick the first urls to reach the number of images we want to download
                urls = urls[:max_results - nb_imgs]
            print(f"Found {len(urls)} images on search page {page}. Downloading into {path2imgs.absolute()}")
            if  skip_download:
                for url in urls:
                    print(url)
            else:
                download_images(path2imgs, urls=urls)
        nb_imgs += len(urls)
        page += 1
    print('All results downloaded')
    print(f"Found {nb_imgs} images for label {label}")

# %%
#| echo: false
DocmentTbl(get_images)
# Out:
# fastcore.docments.DocmentTbl(obj=<function get_images>, dm={'keywords': {'docment': 'string of keywords/query to search for, e.g. "cat", "cat, not dog", "cat OR dog"', 'anno': <class 'str'>, 'default': <class 'inspect._empty'>}, 'label': {'docment': 'label to give to the images found for the keywords/query, e.g. "cat"', 'anno': <class 'str'>, 'default': <class 'inspect._empty'>}, 'path': {'docment': 'path where to download the images, e.g. "data/images"', 'anno': str | pathlib.Path, 'default': <class 'inspect._empty'>}, 'max_results': {'docment': 'maximum number of images to download for the keywords', 'anno': <class 'int'>, 'default': 100}, 'max_pages': {'docment': 'maximum number of search pages to go through to find the images for the keywords', 'anno': <class 'int'>, 'default': 15}, 'skip_download': {'docment': 'if True, only print the urls of the images found without downloading them (for testing purposes)', 'anno': <class 'bool'>, 'default': False}, 'return': {'docment': <class
# ...

# %%
get_images('cat', 'cat', Path('./data-dev'), max_results=10, skip_download=True);
# Out:
# Searching for 10 images for cat (page 1). 0 images found so far...
# Found 10 images on search page 1. Downloading into /home/vtec/projects/ec-packages/nb-guided-dive/nbs-dev/data-dev/cat
# http://clubcatt.com/cdn/shop/articles/domestic-house-cat.png?v=1689444796
# https://www.rd.com/wp-content/uploads/2023/05/GettyImages-1341465008.jpg
# https://betterwithcats.net/wp-content/uploads/2022/08/cat-is-laying-on-a-old-wooden-table.jpg
# https://cdn.pixabay.com/photo/2021/10/13/11/44/cat-6706354_1280.jpg
# https://img.freepik.com/premium-photo/cute-ginger-cat-sitting-looking-camera-isolated-white-background_270100-2630.jpg?w=2000
# https://weheartcats.com/wp-content/uploads/2025/06/domestic-cat-breeds.jpeg
# https://cdn.pixabay.com/photo/2023/12/15/21/47/cat-8451431_1280.jpg
# https://hips.hearstapps.com/hmg-prod/images/cutest-cat-breeds-ragdoll-663a8c6d52172.jpg?crop=0.5989005497251375xw:1xh;center,top&resize=980:*
# ...

# %%
path = Path('./data-dev')
label = 'cat'
get_images(label, label, path, max_results=3, skip_download=False);
print('Downloaded images')
for p in (path/label).ls():
    print('-', p)
    p.unlink()
print('All images deleted')
# Out:
# Searching for 3 images for cat (page 1). 0 images found so far...
# Found 3 images on search page 1. Downloading into /home/vtec/projects/ec-packages/nb-guided-dive/nbs-dev/data-dev/cat
# All results downloaded
# Found 3 images for label cat
# Downloaded images
# - data-dev/cat/96c64472-0c3c-47c9-8b7f-55d66bdf6ac7.jpg
# - data-dev/cat/e3cbc97a-1055-454e-89e3-97b7aa3e5fdd.png
# - data-dev/cat/937c73fe-095f-4b21-b369-c153acef9060.jpg
# All images deleted

# %%
# | export
def clean_image_directory(
    path:Path,          # Path to the directory containing the images
    verbose:bool=False  # if True, print the name of each image being checked and whether it is removed or not.
    ):
    """Remove corrupted images from a directory. If verbose is True, print the name of each image being checked and whether it is removed or not."""
    def check_img(img):
        try: _ = Image.open(img)
        except Exception as e:
            img = str(img).replace(" ","\ ")
            os.system(f"rm -f {img}");
            print(f"removing error img:{img}")

    for cls in path.iterdir():
        print(f"Checking images for class '{cls.name}':")
        for i, img in enumerate(cls.iterdir()):
            if verbose: print(i+1, end=' - ')
            check_img(img)
            if verbose: print('\n')

# %%
#| echo: false
DocmentTbl(clean_image_directory)
# Out:
# fastcore.docments.DocmentTbl(obj=<function clean_image_directory>, dm={'path': {'docment': 'Path to the directory containing the images', 'anno': <class 'pathlib.Path'>, 'default': <class 'inspect._empty'>}, 'verbose': {'docment': 'if True, print the name of each image being checked and whether it is removed or not.', 'anno': <class 'bool'>, 'default': False}, 'return': {'docment': <class 'inspect._empty'>, 'anno': <class 'inspect._empty'>, 'default': <class 'inspect._empty'>}}, verbose=True, returns=True, params=['path', 'verbose'])

# %%
clean_image_directory(Path('./data-dev'), verbose=True)
# Out:
# Checking images for class 'people':
# 1 -
#
# Checking images for class 'cat':
# Checking images for class 'buildings':
# 1 -

# %%
# | export

def count_files(
    path:str | Path,   # Path to the directory containing the images, or any directory to count the number of files in it and its subdirectories. 
    ):
    """Count the number if files in the folder pointed as path, and its subfolders"""
    if isinstance(path, str): path = Path(path)
    nb_img = len([f for f in path.iterdir() if f.is_file()])
    if nb_img > 0:
        print(f"{nb_img:,d} in folder {path.name}")
    counts = {}
    for d in [d for d in path.iterdir() if d.is_dir()]:
        nb_img = len([f for f in d.iterdir() if f.is_file()])
        print(f"{nb_img:,d} in folder {d.name}")
        counts[d.name] = nb_img
    return counts

# %%
#| echo: false
DocmentTbl(count_files)
# Out:
# fastcore.docments.DocmentTbl(obj=<function count_files>, dm={'path': {'docment': 'Path to the directory containing the images, or any directory to count the number of files in it and its subdirectories.', 'anno': str | pathlib.Path, 'default': <class 'inspect._empty'>}, 'return': {'docment': <class 'inspect._empty'>, 'anno': <class 'inspect._empty'>, 'default': <class 'inspect._empty'>}}, verbose=True, returns=True, params=['path'])

# %%
p2images = Path('./data-dev')
count_files(p2images)
# Out:
# 1 in folder people
# 0 in folder cat
# 1 in folder buildings
# {'people': 1, 'cat': 0, 'buildings': 1}

# %%
# | export

def print_metrics(
    cm: np.ndarray,     # Confusion matrix as a 2D numpy array, where cm[i,j] is the number of images of class i predicted as class j. 
    class_0:str='bad',  # Name for class 0
    class_1:str='good'  # Name for class 1
    ):
    """Print FP, FN, Accuracy, Precision  and Recall"""
    nb_val_im = cm.sum()
    true_nb_im_per_class = cm.sum(axis=1)
    pred_nb_im_per_class = cm.sum(axis=0)

    print(f"Accurate predictions:               {cm[0,0] + cm[1,1]:3d} out of {nb_val_im:,d} validation images") 
    print(f"False Positive preds:               {cm[0,1]:3d} images classified as `{class_1}` but actually should be `{class_0}`)")   
    print(f"False Negative preds:               {cm[1,0]:3d} images classified as `{class_0}` but actually should be `{class_1}`)")
    print()
    print(f"Accuracy:                           {cm.diagonal().sum()/nb_val_im * 100:6.2f} %") 
    print(f"{'Precision for '+class_1+':':<33}   {cm[1, 1]/pred_nb_im_per_class[1] * 100:6.2f} %")   
    print(f"{'Recall for '+class_1+':':<33}   {cm[1,1]/true_nb_im_per_class[1] * 100:6.2f} %")

# %%
#| echo: false
DocmentTbl(print_metrics)
# Out:
# fastcore.docments.DocmentTbl(obj=<function print_metrics>, dm={'cm': {'docment': 'Confusion matrix as a 2D numpy array, where cm[i,j] is the number of images of class i predicted as class j.', 'anno': <class 'numpy.ndarray'>, 'default': <class 'inspect._empty'>}, 'class_0': {'docment': 'Name for class 0', 'anno': <class 'str'>, 'default': 'bad'}, 'class_1': {'docment': 'Name for class 1', 'anno': <class 'str'>, 'default': 'good'}, 'return': {'docment': <class 'inspect._empty'>, 'anno': <class 'inspect._empty'>, 'default': <class 'inspect._empty'>}}, verbose=True, returns=True, params=['cm', 'class_0', 'class_1'])

# %%
cm = np.array([[90, 10], [20, 80]])
print_metrics(cm)
# Out:
# Accurate predictions:               170 out of 200 validation images
# False Positive preds:                10 images classified as `good` but actually should be `bad`)
# False Negative preds:                20 images classified as `bad` but actually should be `good`)
#
# Accuracy:                            85.00 %
# Precision for good:                  88.89 %
# Recall for good:                     80.00 %

# %%
#| hide
import nbdev; nbdev.nbdev_export()
